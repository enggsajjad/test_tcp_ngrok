# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd
import csv

# %%
bad_words = ['SSH-2.0','GET','Host','Connection','User','Accept','Cookie']

#replace trash from the file
with open('tcpdata.log') as oldfile, open('newtcpdata.log', 'w') as newfile:
    for line in oldfile:
        if not any(bad_word in line for bad_word in bad_words):
            newfile.write(line);
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_696/2709277008.py in <module>
#       3 #replace trash from the file
#       4 with open('tcpdata.log') as oldfile, open('newtcpdata.log', 'w') as newfile:
# ----> 5     for line in oldfile:
#       6         if not any(bad_word in line for bad_word in bad_words):
#       7             newfile.write(line);
#
# C:\Program Files (x86)\Python39-32\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 5866: character maps to <undefined>

# %%
snr = pd.read_csv('newtcpdata.log')
accData=snr.values.tolist()
accData=np.asarray([np.asarray(elem) for elem in accData])
snr['p1'] = snr['pm25']
snr['p2'] = snr['pm10']
snr['t'] = snr['temp']
snr['h'] = snr['hum']
snr['a'] = snr['atm']
snr['m1'] = snr['m1']


PM25 = np.array(snr['p1'])
PM10 = np.array(snr['p2'])
Temp = np.array(snr['t'])
Hum = np.array(snr['h'])
Atm = np.array(snr['a'])
m = np.linspace(0,np.size(Temp),np.size(Temp))


figure,ax=plt.subplots(1)
#ax.plot(m, P1,'r')
ax.plot(Temp,'r')
ax.set_xlabel(r'measurements',fontsize=15)
ax.set_ylabel(r'Temperature',fontsize=15)

#plt.xlim(0, 300)
plt.ylim(1, 12)


figure,ax=plt.subplots(1)
ax.plot(Hum,'g')
ax.set_xlabel(r'measurements',fontsize=15)
ax.set_ylabel(r'Humidity',fontsize=15)

figure,ax=plt.subplots(1)
ax.plot(Atm,'b')
ax.set_xlabel(r'measurements',fontsize=15)
ax.set_ylabel(r'Atm. Pressure',fontsize=15)

figure,ax=plt.subplots(1)
ax.plot(PM25)
ax.set_xlabel(r'measurements',fontsize=15)
ax.set_ylabel(r'PM25 Particles',fontsize=15)

figure,ax=plt.subplots(1)
ax.plot(PM10)
ax.set_xlabel(r'measurements',fontsize=15)
ax.set_ylabel(r'PM10 Particles',fontsize=15)
# Out:
# Text(0, 0.5, 'PM10 Particles')
